# %% [markdown]
# ## Script to Download Indian Market Stocks Data

# %% [markdown]
# - Script to Download finance data
# - Install yfinace python package from Pipi Website
# -

# %%
# !pip install pyfinance

# %%
import yfinance as yf
import pandas as pd

# %%
# !ls
# Out:
# Companies_Stock_Data  Data_Collection_Script.ipynb  EQUITY_L.csv

# %%
def downloadStockData(st_name):
    df = yf.download(f"{st_name}.NS")
    df.to_csv(f"./Companies_Stock_Data/{st_name}.csv")

# %%
data = yf.download('ADANIGREEN.NS')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2018-06-18 00:00:00+05:30  30.000000  31.500000  28.500000  31.500000
# 2018-06-19 00:00:00+05:30  32.700001  33.049999  31.000000  32.599998
# 2018-06-20 00:00:00+05:30  31.500000  32.200001  31.000000  31.000000
# 2018-06-21 00:00:00+05:30  29.450001  30.000000  29.450001  29.650000
# 2018-06-22 00:00:00+05:30  28.200001  29.799999  28.200001  29.450001
#
#                            Adj Close   Volume
# Date
# 2018-06-18 00:00:00+05:30  31.500000  7006229
# 2018-06-19 00:00:00+05:30  32.599998  2895692
# 2018-06-20 00:00:00+05:30  31.000000  1115553
# 2018-06-21 00:00:00+05:30  29.650000  2854524
# 2018-06-22 00:00:00+05:30  29.450001  1612972

# %%
data.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2023-01-20 00:00:00+05:30  1965.000000  2008.000000  1958.500000  1975.599976
# 2023-01-23 00:00:00+05:30  1986.699951  2009.050049  1911.300049  1931.849976
# 2023-01-24 00:00:00+05:30  1948.900024  1964.199951  1905.000000  1916.800049
# 2023-01-25 00:00:00+05:30  1900.000000  1912.449951  1840.000000  1857.800049
# 2023-01-27 00:00:00+05:30  1780.000000  1796.400024  1486.250000  1486.250000
#
#                              Adj Close   Volume
# Date
# 2023-01-20 00:00:00+05:30  1975.599976  2837568
# 2023-01-23 00:00:00+05:30  1931.849976  1225337
# 2023-01-24 00:00:00+05:30  1916.800049   892161
# 2023-01-25 00:00:00+05:30  1857.800049  1219566
# 2023-01-27 00:00:00+05:30  1486.250000  5837723

# %%
downloadStockData('ADANIGREEN.NS')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ADANIGREEN.NS.NS: No timezone found, symbol may be delisted

# %%
# !ls
# Out:
# Companies_Stock_Data  Data_Collection_Script.ipynb  EQUITY_L.csv

# %%
equity_detail = pd.read_csv('EQUITY_L.csv')

# %%
equity_detail.shape
# Out:
# (1862, 8)

# %%
equity_detail.head()
# Out:
#        SYMBOL                           NAME OF COMPANY  SERIES  \
# 0   20MICRONS                        20 Microns Limited      EQ
# 1  21STCENMGM  21st Century Management Services Limited      EQ
# 2      360ONE                       360 ONE WAM LIMITED      EQ
# 3   3IINFOLTD                       3i Infotech Limited      EQ
# 4     3MINDIA                          3M India Limited      EQ
#
#    DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0      06-OCT-2008               5            1  INE144J01027            5
# 1      03-MAY-1995              10            1  INE253B01015           10
# 2      19-SEP-2019               2            1  INE466L01020            2
# 3      22-OCT-2021              10            1  INE748C01038           10
# 4      13-AUG-2004              10            1  INE470A01017           10

# %%
equity_detail.SYMBOL
# Out:
# 0        20MICRONS
# 1       21STCENMGM
# 2           360ONE
# 3        3IINFOLTD
# 4          3MINDIA
#            ...
# 1857          ZOTA
# 1858         ZUARI
# 1859      ZUARIIND
# 1860     ZYDUSLIFE
# 1861     ZYDUSWELL
# Name: SYMBOL, Length: 1862, dtype: object

# %%
equity_detail[equity_detail['SYMBOL']=='ADANIGREEN']
# Out:
#         SYMBOL             NAME OF COMPANY  SERIES  DATE OF LISTING  \
# 36  ADANIGREEN  Adani Green Energy Limited      EQ      18-JUN-2018
#
#      PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 36              10            1  INE364U01010           10

# %%
for x in equity_detail.SYMBOL:
    downloadStockData(x)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...
